# %% [markdown]
# # First Model for the Prediction of Wakeup Events

# %%
# Import needed libraries and packages
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from imblearn.over_sampling import SMOTE
import xgboost as xgb
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
from sklearn.model_selection import GridSearchCV

import random

import warnings
# To ignore all warnings
warnings.filterwarnings("ignore")

RSEED=42

# %% [markdown]
# ### Getting the Data into Dataframe

# %%
# Define the directory containing the files
data_directory = 'data/file_per_night_08_12'

# %%
# Get a list of all file paths in the directory
file_paths = [os.path.join(data_directory, file) for file in os.listdir(data_directory) if os.path.isfile(os.path.join(data_directory, file))]
dataframes = [pd.read_parquet(file) for file in file_paths]

# Concatenate all dataframes into a single dataframe
full_dataframe = pd.concat(dataframes, ignore_index=True)

# %% [markdown]
# To have only two classes, we set the event 'onset' to 'awake' and 'wakeup' to 'sleep'

# %%
full_dataframe['event'].unique()
# Out:
# array(['awake', 'onset', 'sleep', 'wakeup'], dtype=object)

# %%
for i in full_dataframe.index:
    if full_dataframe['event'][i] == 'onset':
        full_dataframe['event'][i] = 'awake'
    elif full_dataframe['event'][i] == 'wakeup':
        full_dataframe['event'][i] = 'sleep'
    else:
        continue

full_dataframe['event'].unique()
# Out:
# array(['awake', 'sleep'], dtype=object)

# %% [markdown]
# ### Remove Nas

# %%
full_dataframe.isna().sum()
# Out:
# anglez            660
# enmo              660
# step              660
# anglez_std        660
# enmo_std          660
# series_id         660
# night         7276278
# event               0
# dtype: int64

# %%
# remove Nas
full_dataframe.drop('night', axis = 1, inplace =True)
full_dataframe.dropna(inplace=True)

# %%
full_dataframe.isna().sum()
# Out:
# anglez        0
# enmo          0
# step          0
# anglez_std    0
# enmo_std      0
# series_id     0
# event         0
# dtype: int64

# %% [markdown]
# ### Train / Test Split

# %% [markdown]
# Next, we perform the regular train-test-split, training and evaluation of the model as usual:

# %%
# Split the data into train and test sets with stratification
train_data, test_data = train_test_split(full_dataframe, test_size=0.25, stratify=full_dataframe['event'], random_state=RSEED)
# Now train_data and test_data contain your training and testing sets, respectively
train_data = train_data.reset_index(drop=True)
test_data = test_data.reset_index(drop=True)

# %% [markdown]
# Safe the train and test sets for later:

# %%
train_data.to_parquet(os.path.join(data_directory, "train_data.parquet"))
test_data.to_parquet(os.path.join(data_directory, "test_data.parquet"))

# %%
# use this to read the train and test set, if they were already created
train_data = pd.read_parquet(os.path.join(data_directory, "train_data.parquet"))
test_data = pd.read_parquet(os.path.join(data_directory, "test_data.parquet"))

# %%
train_data.head()
# Out:
#       anglez      enmo      step  anglez_std  enmo_std     series_id  \
# 0 -14.223984  0.003942   55889.5   17.420665  0.004248  db75092f0530
# 1 -80.924500  0.000000  267617.5    0.000000  0.000000  8b159a98f485
# 2  28.887924  0.327517  350465.5   12.936250  0.190786  1716cd4163b2
# 3  12.347626  0.026342   62741.5    8.652647  0.016646  7504165f497d
# 4 -30.174082  0.024250  107537.5    1.352014  0.004262  8a22387617c3
#
#    slope_enmo  slope_anglez  anglez_outside_45_counter  enmo_over_008_counter  \
# 0   -0.001044     -2.988206                          0                      3
# 1    0.000000      0.000000                         12                      0
# 2   -0.010472      0.678289                          1                     12
# 3   -0.000198      0.904907                          0                     12
# 4   -0.000633      0.212910                          0                     12
#
#    ...  enmo_10min_std  enmo_10min_mean_shifted  enmo_10min_std_shifted  \
# 0  ...        0.002640                 0.008947                0.017574
# 1  ...        0.000000                 0.000000                0.000000
# 2  ...        0.104317                 0.372927                0.172498
# 3  ...        0.011654                 0.021507                0.005416
# 4  ...        0.004228                 0.027748                0.004891
#
#    event  minutes_since_onset    year  month   day  hour  minute
# 0  awake                  0.0  2018.0    6.0  10.0  18.0    22.0
# 1  sleep                 34.0  2019.0    6.0  12.0  21.0    56.0
# 2  awake                  0.0  2019.0    5.0  23.0  19.0    15.0
# 3  awake                645.0  2017.0    9.0  25.0   7.0    38.0
# 4  awake                  0.0  2018.0    8.0  19.0  21.0    36.0
#
# [5 rows x 34 columns]

# %% [markdown]
# ## Setting up and training of the model

# %% [markdown]
# Model type: XGBoost

# %%
# Extract features and target variable from the data
X_train = train_data.drop(['event', 'series_id', 'step'], axis=1).reset_index(drop=True)
y_train = train_data['event'].reset_index(drop=True)

X_test = test_data.drop(['event', "series_id", "step"], axis=1).reset_index(drop=True)
y_test = test_data['event'].reset_index(drop=True)

# %% [markdown]
# Preprossessing

# %%
# Oversampling (because we have more sleep than awake)
# Apply SMOTE
smote = SMOTE(random_state=RSEED)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)
X_train= X_train_smote
y_train = y_train_smote

# %%
# Preprossessing of features
scaler = MinMaxScaler()

# Scaling of features
scaler.fit_transform(X_train)
scaler.transform(X_test)
# Out:
# array([[5.28688703e-01, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [7.37534316e-01, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [2.41082931e-01, 1.77221463e-03, 3.20157309e-04, 7.63950593e-05],
#        ...,
#        [2.92170747e-01, 7.33863329e-04, 5.47116460e-03, 3.01475693e-03],
#        [5.00229008e-01, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [5.26568292e-01, 1.07355760e-02, 4.77040173e-01, 1.65226161e-02]])

# %%
# Preprossessing of target

def prepro(y):
    for i in range(len(y)):
        if y[i] == 'awake':
            y[i] = 1
        else: 
            y[i] = 0
    return y

# %%
prepro(y_train)
prepro(y_test)
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          1
#           ..
# 1821295    0
# 1821296    1
# 1821297    0
# 1821298    0
# 1821299    1
# Name: event, Length: 1821300, dtype: object

# %%
# Initialize the Classifier
model = xgb.XGBClassifier(tree_method="hist")

# %%
# Train the model on the training data
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
# Make predictions on the test data
y_pred = model.predict(X_test)

# %% [markdown]
# Evaluation of the model performance:

# %%
accuracy = accuracy_score(list(y_test), list(y_pred))
precision = precision_score(list(y_test), list(y_pred), average='weighted')
recall = recall_score(list(y_test), list(y_pred), average='weighted')
f1 = f1_score(list(y_test), list(y_pred), average='weighted')

print(f"Accuracy on test data: {accuracy:.2%}")
print(f"Precision on test data: {precision:.2%}")
print(f"Recall on test data: {recall:.2%}")
print(f"F1 Score on test data: {f1:.2%}")
# Out:
# Accuracy on test data: 88.51%
# Precision on test data: 89.01%
# Recall on test data: 88.51%
# F1 Score on test data: 88.66%

# %%
# Compute confusion matrix
cm = confusion_matrix(list(y_test), list(y_pred))

# Plot confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ## Grid Search

# %% [markdown]
# To find a better performing model, we perform a grid search testing different parameters:

# %%
# Define the parameter grid to search
param_grid = {
    'tree_method': ['hist'],
    'verbosity': [2],
    'n_estimators': [7, 10],
    'max_depth': [5, 10, 20],
}

# Initialize the Decision Tree Classifier
modelCV = xgb.XGBClassifier(tree_method="hist")

# %%
# Perform grid search with cross-validation
grid_search = GridSearchCV(modelCV, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid_search.fit(X_train, y_train)
# Out:
# python(34048) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(34050) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(34051) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(34052) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(34053) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(34054) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(34055) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(34056) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# /Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 355, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 220, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tabeanoethe-menchen/capstone/sleepy_kid_Zzzz/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
#
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'max_depth': [5, 10, 20], 'n_estimators': [7, 10],
#                          'tree_method': ['hist'], 'verbosity': [2]},
#              scoring='accuracy')

# %%
# Print the best parameters and corresponding accuracy
best_params = grid_search.best_params_
print("Best Parameters:", grid_search.best_params_)
# Out:
# Best Parameters: {'max_depth': 5, 'n_estimators': 2, 'tree_method': 'hist', 'verbosity': 2}

# %%
best_model = xgb.XGBClassifier(max_depth = 5, n_estimators = 5)

# %%
best_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=5, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_pred_best = best_model.predict(X_test)

# %%
accuracy = accuracy_score(list(y_test), list(y_pred_best))
precision = precision_score(list(y_test), list(y_pred_best), average='weighted')
recall = recall_score(list(y_test), list(y_pred_best), average='weighted')
f1 = f1_score(list(y_test), list(y_pred_best), average='weighted')

print(f"Accuracy on test data: {accuracy:.2%}")
print(f"Precision on test data: {precision:.2%}")
print(f"Recall on test data: {recall:.2%}")
print(f"F1 Score on test data: {f1:.2%}")
# Out:
# Accuracy on test data: 87.65%
# Precision on test data: 88.51%
# Recall on test data: 87.65%
# F1 Score on test data: 87.86%

# %%
# Compute confusion matrix
cm = confusion_matrix(list(y_test), list(y_pred_best))

# Plot confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
